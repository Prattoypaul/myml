# %% [markdown]
# <a href="https://colab.research.google.com/github/Prattoypaul/myml/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers,datasets,models
import matplotlib.pyplot as plt
import  numpy as np
import os
import matplotlib.image as mpimg

# %%
import cv2
import PIL.Image as Image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import tensorflow_hub as hub

# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/1d/a2/5ccf0a418eb22e0a2ae9edc1e7f5456d0a4b8b49524572897564b4030a9b/tensorflow_gpu-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3MB)
#      |████████████████████████████████| 454.3MB 36kB/s
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.12.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.19.5)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.36.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0.dev2021032900)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.34.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.12.4)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (57.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu) (4.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (0.4.8)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.5.0

# %%
# !nvidia-smi
# Out:
# Wed Jun 23 09:55:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
CATEGORIES=['sakib','ronaldo','Musfiq','messi',]

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
img_size=[244,244]
img_dir='/content/gdrive/MyDrive/Colab Notebooks/project2/players'

# %%
inception=InceptionV3(input_shape=img_size+[3],weights='imagenet',include_top=False)

# %%
img_shape=(224,224)

# %%
data=[]
for Catagories in CATEGORIES:
  Folder=os.path.join(img_dir,Catagories)
  label=CATEGORIES.index(Catagories)

  for img in os.listdir(Folder):
    image=os.path.join(Folder,img)
    
    image_arr=cv2.imread(image)
    
    try:
      image_arr=cv2.resize(image_arr,img_shape, interpolation=cv2.INTER_AREA)   
    except:
      break
    data.append([image_arr,label])

# %%
from tensorflow import keras

# %%
data_augmantation=keras.Sequential([
                                    layers.experimental.preprocessing.RandomFlip(),
                                    layers.experimental.preprocessing.RandomRotation(0.1),
                                    layers.experimental.preprocessing.RandomZoom(0.1)

])

# %%
import random
random.shuffle(data)
x=[]
y=[]
for feature,label in data :
  x.append(feature)
  y.append(label)

x=np.array(x)
y=np.array(y)

x=x/255

# %%
plt.imshow(x[0])

# %%
y[0]
# Out:
# 2

# %%
def plot_labal(x,y,i):
  plt.imshow(x[i])
  plt.xlabel(CATEGORIES[y[i]])

# %%
plot_labal(x,y,0)

# %%
x.shape
# Out:
# (427, 224, 224, 3)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
ann=models.Sequential([
                       data_augmantation,
                       layers.Flatten(input_shape=(224,224,3)),
                       layers.Dense(3000,activation='relu'),
                       layers.Dense(1000,activation='relu'),
                       layers.Dense(10,activation='softmax'),
])
ann.compile(
    optimizer='SGD',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
ann.fit(xtrain,ytrain,epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 10/10 [==============================] - 1s 59ms/step - loss: 9.7211 - accuracy: 0.2215
# Epoch 2/10
# 10/10 [==============================] - 1s 56ms/step - loss: 1.8872 - accuracy: 0.2349
# Epoch 3/10
# 10/10 [==============================] - 1s 54ms/step - loss: 1.6676 - accuracy: 0.2718
# Epoch 4/10
# 10/10 [==============================] - 1s 57ms/step - loss: 1.5183 - accuracy: 0.2953
# Epoch 5/10
# 10/10 [==============================] - 1s 54ms/step - loss: 1.5200 - accuracy: 0.2483
# Epoch 6/10
# 10/10 [==============================] - 1s 56ms/step - loss: 1.4137 - accuracy: 0.3289
# Epoch 7/10
# 10/10 [==============================] - 1s 56ms/step - loss: 1.4519 - accuracy: 0.2886
# Epoch 8/10
# 10/10 [==============================] - 1s 56ms/step - loss: 1.4870 - accuracy: 0.3289
# Epoch 9/10
# 10/10 [==============================] - 1s 56ms/step - loss: 1.3633 - accuracy: 0.3591
# Epoch 10/10
# 10/10 [==============================] - 1s 54ms/step - loss: 1.3840 - accuracy: 0.3456

# %%
cnn=models.Sequential([
                       data_augmantation,
                       layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)),
                       layers.MaxPool2D((2,2)),
                       layers.Conv2D(filters=64,kernel_size=(3,3),activation='relu'),
                       layers.MaxPool2D((2,2)),

                       layers.Flatten(),
                       layers.Dense(1000,activation='relu'),
                       layers.Dense(10,activation='softmax')
])
cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
cnn.fit(xtrain,ytrain,epochs=50)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 85ms/step - loss: 0.3384 - accuracy: 0.8792
# Epoch 2/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2668 - accuracy: 0.8993
# Epoch 3/50
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3225 - accuracy: 0.8624
# Epoch 4/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.3276 - accuracy: 0.8859
# Epoch 5/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2603 - accuracy: 0.9094
# Epoch 6/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2734 - accuracy: 0.8960
# Epoch 7/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2785 - accuracy: 0.9060
# Epoch 8/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2926 - accuracy: 0.8926
# Epoch 9/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2679 - accuracy: 0.9094
# Epoch 10/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.3070 - accuracy: 0.8859
# Epoch 11/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2655 - accuracy: 0.8960
# Epoch 12/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2413 - accuracy: 0.8993
# Epoch 13/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2158 - accuracy: 0.9329
# Epoch 14/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2178 - accuracy: 0.9463
# Epoch 15/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2280 - accuracy: 0.9027
# Epoch 16/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1787 - accuracy: 0.9262
# Epoch 17/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1679 - accuracy: 0.9430
# Epoch 18/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2351 - accuracy: 0.9228
# Epoch 19/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1761 - accuracy: 0.9396
# Epoch 20/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1311 - accuracy: 0.9463
# Epoch 21/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1835 - accuracy: 0.9295
# Epoch 22/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1793 - accuracy: 0.9362
# Epoch 23/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1429 - accuracy: 0.9597
# Epoch 24/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1087 - accuracy: 0.9698
# Epoch 25/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1344 - accuracy: 0.9530
# Epoch 26/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1568 - accuracy: 0.9530
# Epoch 27/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1589 - accuracy: 0.9362
# Epoch 28/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1370 - accuracy: 0.9530
# Epoch 29/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2347 - accuracy: 0.8993
# Epoch 30/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1633 - accuracy: 0.9295
# Epoch 31/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2074 - accuracy: 0.9228
# Epoch 32/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1773 - accuracy: 0.9329
# Epoch 33/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1840 - accuracy: 0.9195
# Epoch 34/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2115 - accuracy: 0.9060
# Epoch 35/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1729 - accuracy: 0.9430
# Epoch 36/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2275 - accuracy: 0.9295
# Epoch 37/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1611 - accuracy: 0.9396
# Epoch 38/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1057 - accuracy: 0.9597
# Epoch 39/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1649 - accuracy: 0.9430
# Epoch 40/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1348 - accuracy: 0.9530
# Epoch 41/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0963 - accuracy: 0.9698
# Epoch 42/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1275 - accuracy: 0.9497
# Epoch 43/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0858 - accuracy: 0.9698
# Epoch 44/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0618 - accuracy: 0.9799
# Epoch 45/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0975 - accuracy: 0.9664
# Epoch 46/50
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1070 - accuracy: 0.9631
# Epoch 47/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1231 - accuracy: 0.9463
# Epoch 48/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0900 - accuracy: 0.9732
# Epoch 49/50
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1103 - accuracy: 0.9631
# Epoch 50/50
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1070 - accuracy: 0.9664

# %%
cnn.evaluate(xtest,ytest)
# Out:
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6200 - accuracy: 0.5969
# [2.620044231414795, 0.5968992114067078]

# %%
xtest[0]
# Out:
# array([[[0.54509804, 0.57647059, 0.58431373],
#         [0.57647059, 0.57647059, 0.57647059],
#         [0.57647059, 0.57647059, 0.60784314],
#         ...,
#         [0.51372549, 0.49803922, 0.65882353],
#         [0.49019608, 0.4745098 , 0.68235294],
#         [0.48235294, 0.45882353, 0.70196078]],
#
#        [[0.58431373, 0.60392157, 0.61960784],
#         [0.60784314, 0.59607843, 0.58823529],
#         [0.59215686, 0.59215686, 0.6       ],
#         ...,
#         [0.5254902 , 0.51372549, 0.64313725],
#         [0.49411765, 0.47843137, 0.64313725],
#         [0.47058824, 0.44705882, 0.63137255]],
#
#        [[0.63529412, 0.63921569, 0.6627451 ],
#         [0.65098039, 0.63529412, 0.61568627],
#         [0.63921569, 0.63137255, 0.61568627],
#         ...,
#         [0.55294118, 0.54509804, 0.63137255],
#         [0.52941176, 0.51764706, 0.61960784],
#         [0.49019608, 0.4745098 , 0.57254902]],
#
#        ...,
#
#        [[0.52156863, 0.68235294, 0.57647059],
#         [0.52156863, 0.68235294, 0.57647059],
#         [0.52156863, 0.68235294, 0.57647059],
#         ...,
#         [0.48235294, 0.67058824, 0.55686275],
#         [0.4745098 , 0.6627451 , 0.54901961],
#         [0.4745098 , 0.6627451 , 0.54901961]],
#
#        [[0.52156863, 0.68235294, 0.57647059],
#         [0.52156863, 0.68235294, 0.57647059],
#         [0.52156863, 0.68235294, 0.57647059],
#         ...,
#         [0.4745098 , 0.6627451 , 0.54901961],
#         [0.4745098 , 0.6627451 , 0.54901961],
#         [0.4745098 , 0.6627451 , 0.54901961]],
#
#        [[0.51372549, 0.6745098 , 0.56470588],
#         [0.51372549, 0.6745098 , 0.56470588],
#         [0.51372549, 0.6745098 , 0.56470588],
#         ...,
#         [0.4627451 , 0.65098039, 0.5372549 ],
#         [0.4627451 , 0.65098039, 0.53333333],
#         [0.4627451 , 0.65490196, 0.52941176]]])

# %%
xtest.shape
# Out:
# (129, 224, 224, 3)

# %%
ypred=cnn.predict(xtest)
ypred_class=[np.argmax(i) for i in ypred]

# %%
ypred_class[:10]
# Out:
# [1, 1, 3, 1, 2, 2, 3, 3, 1, 0]

# %%
ytest[:10]
# Out:
# array([1, 1, 3, 1, 2, 2, 3, 2, 1, 2])

# %%
plot_labal(xtest,ytest,1)

# %%
ypred_class[0]
# Out:
# 3

# %%
plot_labal(xtest,ytest,6)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print('classification_report \n' ,classification_report(ytest,ypred_class))
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.46      0.66      0.54        29
#            1       0.67      0.80      0.73        30
#            2       0.77      0.32      0.45        31
#            3       0.74      0.74      0.74        39
#
#     accuracy                           0.64       129
#    macro avg       0.66      0.63      0.62       129
# weighted avg       0.67      0.64      0.63       129
